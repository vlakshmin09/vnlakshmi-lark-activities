# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('week06.xlsx')
df
# Out:
#        1                             country             Region  \
# 0      2                         Afghanistan       SouthernAsia
# 1      3                             Albania     SouthernEurope
# 2      4                             Algeria     NorthernAfrica
# 3      5                              Angola       MiddleAfrica
# 4      6                 Antigua and Barbuda          Caribbean
# ..   ...                                 ...                ...
# 191  193  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192  194                            Viet Nam  South-easternAsia
# 193  195                               Yemen        WesternAsia
# 194  196                              Zambia      EasternAfrica
# 195  197                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0                652864                           35530
# 1                 28748                            2930
# 2               2381741                           41318
# 3               1246700                           29784
# 4                   442                             102
# ..                  ...                             ...
# 191              912050                           31977
# 192              330967                           95541
# 193              527968                           28250
# 194              752612                           17094
# 195              390757                           16530
#
#      GDP per capita (current US$)  Agricultural production index  \
# 0                           623.2                            125
# 1                          3984.2                            134
# 2                          4154.1                            160
# 3                          4714.1                            175
# 4                         14764.5                             88
# ..                            ...                            ...
# 191                       11068.9                            118
# 192                        2067.9                            136
# 193                        1106.4                            136
# 194                        1311.1                            179
# 195                         890.4                             99
#
#      International trade: Imports (million US$)
# 0                                          3568
# 1                                          4669
# 2                                         47091
# 3                                          8790
# 4                                           491
# ..                                          ...
# 191                                       16324
# 192                                      174111
# 193                                        6861
# 194                                        7442
# 195                                        5212
#
# [196 rows x 8 columns]

# %%
data=df.groupby('Region').agg({'Surface area (km2)':'sum','Population in thousands (2017)':'sum'})

# %%
plt.figure(figsize=(8,12))
labels=df['Region'].value_counts().index

plt.pie(data['Population in thousands (2017)'],labels=labels,autopct='%1.1f%%')
plt.title('population in thousands (2017)')
plt.show()

# %%
data2=data.sort_values(['Population in thousands (2017)'],ascending=False)
plt.figure(figsize=(8,12))
data2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
data3=df.sort_values(['GDP per capita (current US$)'],ascending=False).head(10)
labels=data3['country'].value_counts().index
plt.pie(data3['GDP per capita (current US$)'],labels=labels,autopct='%1.1f%%')
plt.title('GDP per capita (current US$) in percentage')
plt.show()

# %%
sns.pairplot(df)

# %%
#  Find out how many countries are there in the data set

# %%
df['country'].count()
# Out:
# 196

# %% [markdown]
# # Find out how many countries with respect to the region are available in the dataset

# %%
df['Region'].value_counts()
# Out:
# WesternAsia          18
# EasternAfrica        17
# Caribbean            16
# WesternAfrica        15
# SouthAmerica         12
# SouthernEurope       12
# South-easternAsia    11
# EasternEurope        10
# NorthernEurope       10
# SouthernAsia          9
# MiddleAfrica          9
# CentralAmerica        8
# WesternEurope         7
# EasternAsia           7
# SouthernAfrica        5
# Polynesia             5
# NorthernAfrica        5
# Melanesia             5
# CentralAsia           5
# NorthernAmerica       4
# Micronesia            4
# Oceania               2
# Name: Region, dtype: int64

# %%
#  On average which region has the highest GDP per capita (current US$)

# %%
df1=df.groupby('Region')['GDP per capita (current US$)'].agg(['mean'])
df1[df1['mean']==max(df1['mean'])]
# Out:
#                     mean
# Region
# NorthernAmerica  57659.0

# %%
# On average which region has the highest International trade: Imports (million US$)

# %%
df2=df.groupby('Region')['International trade: Imports (million US$)'].agg(['mean'])
df2[df2['mean']==max(df2['mean'])]
# Out:
#                       mean
# Region
# NorthernAmerica  663552.25

# %%
 #  Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
df3=df.groupby('Region')['GDP per capita (current US$)'].agg(['std'])
df3[df3['std']==min(df3['std'])]
# Out:
#                       std
# Region
# WesternAfrica  815.095399
